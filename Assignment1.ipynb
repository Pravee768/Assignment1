# %% [markdown]
# Question(1): In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.
# *
# 'hello'
# -87.8
# -
# /
# +
# 6
# Solution: In the above question, Values and extressions are as follow
# Values :'hello' , -87.8 , 6
# Expression: * , - , / , +
#
# Question(2): What is the difference between string and variable?
# Solution: There are following differecnces between string and variabls
#
# Variabls: Variables are symbols that could be use to hold the different types of data like integers, flote, string etc.
#
# String: A string is a sequence of one or more characters that can either a constant and variable. String is a one type of fundamental data type, which is use in Python programing.
#
# Question(3): Describe three different data types.
#
# Solution: Three different data types in Python are:
# Int, float and complex
#
# int(integers data type like 1, 3 etc): They are positive or negative whole numbers with no decimal point.
#
# float(float data type like 10.23, 3.89 etc): float values are specified with a decimal point.
#
# complex(complet data type like 4 + 10j): Complex data type could be represented by a + bj where a is real part and b is imaginery part.
#
# Question(4): What is an expression made up of? What do all expressions do?
#
# Solution: Expression is a combination of variables, operations and values that yields a result value.
# Expressions are representations of value.
#
# Question(5): This assignment statements, like spam = 10. What is the difference between an expression and a statement?
#
# Solution: Any Instruction that a python interpreter can execute (carry out) is called a Statement. Statements represent an action or command e.g print statements, assignment statements. Expression is a combination of variables, operations and values that yields a result value.
#
#
# Question(6): After running the following code, what does the variable bacon contain?
# bacon = 22
# bacon + 1
#
# Solution:
# After running above code, result: bacon = 23
#
# Question(7): What should the values of the following two terms be?
# 'spam' + 'spamspam'
# 'spam' * 3
#
# Solution:
# Output of 'spam' + 'spamspam' is 'spamspamspam'
# Output of 'spam' * 3 is 'spamspamspam'
#
#
# Question(8): Why is eggs a valid variable name while 100 is invalid?
# Solution:
# Variable name should not start wirh digits, so eggs is a valid variable and 100 is not a valid variable.
#
# Question(9): What three functions can be used to get the integer, floating-point number, or string version of a value?
# Solution:
# The int() , float() , and str( ) functions will evaluate to the integer, floating-point number, and string versions of the value passed to them.
#
# Question(10): Why does this expression cause an error? How can you fix it?
# 'I have eaten ' + 99 + ' burritos.'
#
# Solution: in the above expression 'I have eaten ' + 99 + ' burritos ' 'I have eaten ' is a string and ' burritos ' is also a string but 99 is an integer. so it will through error. if i change 99 as '99' then it will not through an error. concatenate will happen only str to str.
